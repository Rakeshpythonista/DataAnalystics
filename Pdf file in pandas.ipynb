# %%
import pandas as pd
import numpy as np
import tabula

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
file_path = 'D:/130421/Project_DataAnalysis_ReportOnHRData.pdf'
raw_data = tabula.read_pdf(file_path, pages="all")
df = raw_data.copy()

# %%
df[0]
# Out:
#                    Name  Start Date    End Date   Department  \
# 0       Walter J Miller  15-01-2020         NaN        Sales
# 1       Alissa Mitchell  11-06-2019         NaN    Marketing
# 2        Andre C Cooper  02-10-2018         NaN  Procurement
# 3           Ann Withers  02-09-2019  03-02-2020  Procurement
# 4           Ann Withers  03-02-2020         NaN  Procurement
# 5              Kim West  01-02-2018         NaN        Sales
# 6      Daniel A Garrett  01-08-2017         NaN      Finance
# 7       Lyric Nate Wise  24-04-2018         NaN        Sales
# 8        Robert Marquez  01-03-2017         NaN  Procurement
# 9        Vanessa Chavez  29-11-2017         NaN        Sales
# 10        Brylee Hunter  31-05-2017         NaN  Procurement
# 11        Robert Musser  01-10-2018         NaN  Procurement
# 12            Reid Good  14-03-2017         NaN        Sales
# 13  Christopher P Sharp  22-08-2016         NaN        Sales
# ...

# %%
df[1]
# Out:
#          James Willard  02-12-2013  Unnamed: 0        Sales  \
# 0          Lukas Hofer  24-09-2018         NaN      Finance
# 1            Jude Bell  11-10-2013         NaN  Procurement
# 2         Heidi Medina  27-06-2014         NaN    Marketing
# 3         Ashton Kelly  13-08-2013         NaN  Procurement
# 4         Matthew Ross  24-07-2015         NaN  Procurement
# 5          Esme Carney  20-06-2016         NaN  Procurement
# 6         Zac Fletcher  15-07-2013         NaN        Sales
# 7      Kristina Mclean  27-12-2013         NaN        Sales
# 8            Maria Tot  05-01-2015         NaN        Sales
# 9      Wolfgang Ramjac  01-07-2002         NaN        Sales
# 10            Tom Wood  08-05-2013         NaN  Procurement
# 11         Peter Ramsy  03-05-2010         NaN        Sales
# 12        Betina Bauer  03-01-2019         NaN  Procurement
# 13         Cora Briggs  16-09-2013         NaN  Procurement
# 14     Matilda Collier  28-05-2013         NaN        Sales
# ...

# %%
df[0].columns
# Out:
# Index(['Name', 'Start Date', 'End Date', 'Department', 'Position', 'Salary'], dtype='object')

# %%
df[1] = df[1].columns.to_frame().T.append(df[1], ignore_index=True)

# %%
df[1].columns = df[0].columns

# %%
df[1]
# Out:
#                   Name  Start Date    End Date   Department  \
# 0        James Willard  02-12-2013  Unnamed: 0        Sales
# 1          Lukas Hofer  24-09-2018         NaN      Finance
# 2            Jude Bell  11-10-2013         NaN  Procurement
# 3         Heidi Medina  27-06-2014         NaN    Marketing
# 4         Ashton Kelly  13-08-2013         NaN  Procurement
# 5         Matthew Ross  24-07-2015         NaN  Procurement
# 6          Esme Carney  20-06-2016         NaN  Procurement
# 7         Zac Fletcher  15-07-2013         NaN        Sales
# 8      Kristina Mclean  27-12-2013         NaN        Sales
# 9            Maria Tot  05-01-2015         NaN        Sales
# 10     Wolfgang Ramjac  01-07-2002         NaN        Sales
# 11            Tom Wood  08-05-2013         NaN  Procurement
# 12         Peter Ramsy  03-05-2010         NaN        Sales
# 13        Betina Bauer  03-01-2019         NaN  Procurement
# 14         Cora Briggs  16-09-2013         NaN  Procurement
# ...

# %%
hr_data = pd.concat([df[0],df[1]], ignore_index=True)

# %%
hr_data
# Out:
#                    Name  Start Date    End Date   Department  \
# 0       Walter J Miller  15-01-2020         NaN        Sales
# 1       Alissa Mitchell  11-06-2019         NaN    Marketing
# 2        Andre C Cooper  02-10-2018         NaN  Procurement
# 3           Ann Withers  02-09-2019  03-02-2020  Procurement
# 4           Ann Withers  03-02-2020         NaN  Procurement
# 5              Kim West  01-02-2018         NaN        Sales
# 6      Daniel A Garrett  01-08-2017         NaN      Finance
# 7       Lyric Nate Wise  24-04-2018         NaN        Sales
# 8        Robert Marquez  01-03-2017         NaN  Procurement
# 9        Vanessa Chavez  29-11-2017         NaN        Sales
# 10        Brylee Hunter  31-05-2017         NaN  Procurement
# 11        Robert Musser  01-10-2018         NaN  Procurement
# 12            Reid Good  14-03-2017         NaN        Sales
# 13  Christopher P Sharp  22-08-2016         NaN        Sales
# ...

# %%
hrd = hr_data.copy()

# %%
hrd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        76 non-null     object
#  1   Start Date  76 non-null     object
#  2   End Date    6 non-null      object
#  3   Department  76 non-null     object
#  4   Position    76 non-null     object
#  5   Salary      76 non-null     object
# dtypes: object(6)
# memory usage: 3.7+ KB

# %%
hrd['End Date'].unique()
# Out:
# array([nan, '03-02-2020', '03-06-2019', '02-01-2020', '02-03-2020',
#        'Unnamed: 0', '03-09-2018'], dtype=object)

# %%
hrd['End Date'].iloc[40]
# Out:
# 'Unnamed: 0'

# %%
# np.nan
hrd['End Date'].iloc[40] = np.nan

# %%
hrd[hrd['End Date'].isnull() == True]
# Out:
#                    Name  Start Date End Date   Department  \
# 0       Walter J Miller  15-01-2020      NaN        Sales
# 1       Alissa Mitchell  11-06-2019      NaN    Marketing
# 2        Andre C Cooper  02-10-2018      NaN  Procurement
# 4           Ann Withers  03-02-2020      NaN  Procurement
# 5              Kim West  01-02-2018      NaN        Sales
# 6      Daniel A Garrett  01-08-2017      NaN      Finance
# 7       Lyric Nate Wise  24-04-2018      NaN        Sales
# 8        Robert Marquez  01-03-2017      NaN  Procurement
# 9        Vanessa Chavez  29-11-2017      NaN        Sales
# 10        Brylee Hunter  31-05-2017      NaN  Procurement
# 11        Robert Musser  01-10-2018      NaN  Procurement
# 12            Reid Good  14-03-2017      NaN        Sales
# 13  Christopher P Sharp  22-08-2016      NaN        Sales
# 14         Jessica Lowe  11-01-2017      NaN        Sales
# 15      Evie Williamson  20-12-2016      NaN        Sales
# ...

# %%
hrd['End Date'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28    False
# 29    False
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40    False
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53     True
# 54     True
# 55     True
# 56     True
# 57     True
# 58     True
# 59     True
# 60     True
# 61     True
# 62     True
# 63     True
# 64     True
# 65     True
# 66     True
# 67    False
# 68     True
# 69     True
# 70     True
# ...

# %%
hrd['End Date'].fillna('Not', inplace=True)

# %%
hrd
# Out:
#                    Name  Start Date    End Date   Department  \
# 0       Walter J Miller  15-01-2020         Not        Sales
# 1       Alissa Mitchell  11-06-2019         Not    Marketing
# 2        Andre C Cooper  02-10-2018         Not  Procurement
# 3           Ann Withers  02-09-2019  03-02-2020  Procurement
# 4           Ann Withers  03-02-2020         Not  Procurement
# 5              Kim West  01-02-2018         Not        Sales
# 6      Daniel A Garrett  01-08-2017         Not      Finance
# 7       Lyric Nate Wise  24-04-2018         Not        Sales
# 8        Robert Marquez  01-03-2017         Not  Procurement
# 9        Vanessa Chavez  29-11-2017         Not        Sales
# 10        Brylee Hunter  31-05-2017         Not  Procurement
# 11        Robert Musser  01-10-2018         Not  Procurement
# 12            Reid Good  14-03-2017         Not        Sales
# 13  Christopher P Sharp  22-08-2016         Not        Sales
# ...
